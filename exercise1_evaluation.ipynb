# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
hr_image = cv2.imread("data/Set5/butterfly_GT.bmp")[:,:,::-1]

# %%
plt.imshow(hr_image)

# %%
## Resize the image to lower scale and resize back
## You can use different resize method 
lr_image = cv2.resize(cv2.resize(hr_image, (32, 32), cv2.INTER_NEAREST), (256, 256), cv2.cv2.INTER_NEAREST)

# %%
plt.imshow(lr_image)

# %% [markdown]
# ## Practice
# - Calculate the PSNR, SSIM by using the hr image and lr image. See this [reference](https://medium.com/@datamonsters/a-quick-overview-of-methods-to-measure-the-similarity-between-images-f907166694ee) for more details about the differences of PSNR and SSIM

# %%
from skimage.metrics import peak_signal_noise_ratio, structural_similarity
